# %%
#Load CSVs (customers, orders, order_items)

#Check for missing values, duplicates, incorrect types

#Merge tables using primary keys (customer_id, order_id)

#Save a “cleaned” combined dataset if needed

# %%
#import
import os
import pandas as pd
